# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
from datetime import datetime
import ast
import time
import os

# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Mounted at /gdrive

# %%
df1 = pd.read_csv("/gdrive/My Drive/Colab Notebooks/scrollfinalkroysmatacleanedcsv.csv")
df1
# Out:
#                                                headline  ...                                           comments
# 0     \nΚρούσματα κορωνοϊού σε 50 περιοχές - Απαγορε...  ...  \n\n\n                        Πόση \n         ...
# 1     \nΝέο μαύρο ρεκόρ κρουσμάτων κορωνοϊού στην Το...  ...                                        NO COMMENTS
# 2     \nΚύπρος: Δύο νέοι θάνατοι και 363 κρούσματα κ...  ...                                        NO COMMENTS
# 3     \nΓαλλία: Μεγάλη διασπορά με 14.595 νέα κρούσμ...  ...                                        NO COMMENTS
# 4     \nΚορωνοϊός - Πάτρα: Τέσσερα κρούσματα στο Άσυ...  ...                                        NO COMMENTS
# ...                                                 ...  ...                                                ...
# 5273  \nΚορωνοϊός: Έφτασε και στο μακρινό και απομον...  ...                                        NO COMMENTS
# ...

# %%
df1 = df1[df1.comments != 'NO COMMENTS'] 
df1
# Out:
#                                                headline  ...                                           comments
# 0     \nΚρούσματα κορωνοϊού σε 50 περιοχές - Απαγορε...  ...  \n\n\n                        Πόση \n         ...
# 6     \nΠάτρα: Τέσσερα κρούσματα κορωνοϊού σε Άσυλο ...  ...  \n\n\n                        Πυργιώτης\n     ...
# 7     \nΣτα 1.677 τα νέα κρούσματα - 578 διασωληνωμέ...  ...  \n\n\n                        karantinatos\n  ...
# 9     \nΔεν βλέπουμε την αναμενόμενη βελτίωση, λέει ...  ...  \n\n\n                        Μα... πώς Μανώλη...
# 10    \nΈχασε τη μάχη με τον κορωνοϊό 51χρονη διοικη...  ...  \n\n\n                        mm\n            ...
# ...                                                 ...  ...                                                ...
# 5270  \nΚορωνοϊός - Ρουμανία: Πρόστιμο σε πολίτη που...  ...  \n\n\n                        Φαπ φαπ φαπ\n   ...
# ...

# %%
df1.comments.iloc[1]
# Out:
# '\n\n\n                        Πυργιώτης\n                    \n09/12/2020, 20:31\n\n\n\n                        Τι πρωτόκολλο εφάρμοσες εκεί κ. Χαρδαλιά? Όπως αποδεικνύεται,  οι ικανότητες σου σταματούν στα πρόστιμα που δίνεις σε γριούλες έξω από εκκλησίες. \n                    \n\n\nΑπάντηση\n\n$$\n\n\n                        !!!!!\n                    \n09/12/2020, 20:29\n\n\n\n                        ΝΟΣΟΚΟΜΕΙΑ ΓΗΡΟΚΟΜΕΙΑ ΦΥΛΑΚΕΣ ΙΔΡΥΜΑΤΑ....ΕΣΤΙΕΣ ΜΟΛΥΝΣΗΣ......ΠΟΛΥ ΕΥΚΟΛΟ ΝΑ ΤΑ ΕΛΕΓΞΟΥΝ...ΑΛΛΑ ΔΕΝ ΤΟ ΚΑΝΟΥΝ.....Ο ΚΟΣΜΟΣ ΠΡΟΣΕΧΕΙ......ΑΛΛΑ ΠΛΗΡΩΝΕΙ ΤΟ ΚΛΕΙΣΙΜΟ ΚΑΙ ΤΗΝ ΚΑΤΑΣΤΡΟΦΗ ΤΗΣ ΟΙΚΟΝΟΜΙΑΣ.....ΠΡΩΤΑ ΕΦΤΑΙΓΑΝ ΤΑ ΚΑΦΕ ΚΑΙ ΤΑ ΕΣΤΙΑΤΟΡΙΑ...ΚΑΤΕ ΜΕ ....ΛΑΘΟΣ.....ΤΩΡΑ Η ΟΙΚΟΓΕΝΕΙΑ....ΚΑΤΕΜΕ...ΛΑΘΟΣ.....ΚΑΙΡΟΣ ΝΑ ΜΠΟΥΝ ΤΑ ΠΡΑΓΜΑΤΑ ΣΤΗΝ ΘΕΣΗ ΤΟΥΣ...ΠΟΛΛΑ ΤΕΣΤ ΣΕ ΟΛΕΣ ΤΙΣ ΔΟΜΕΣ.....ΙΔΡΥΜΑΤΑ ...ΝΟΣΟΚΟΜΕΙΑ ΚΤΛ,....ΑΛΛΙΩΣ ΔΕΝ ΘΑ  ΤΕΛΕΙΩΣΕΙ...Η ΠΑΝΔΗΜΙΑ\n                    \n\n\nΑπάντηση\n\n'

# %%
olga =[]
for comment in df1["comments"]:
  listcom = comment.splitlines()
  
  for com in listcom:
    olga.append(com)
  print(listcom)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# ...

# %%
df1.replace(r'\s+|\\n', ' ', regex=True, inplace=True) 
df1
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py:4389: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   method=method,
#                                                headline  ...                                           comments
# 0      Κρούσματα κορωνοϊού σε 50 περιοχές - Απαγορευ...  ...   Πόση 10/12/2020, 12:50 βλακεία πιά...με την Α...
# 6      Πάτρα: Τέσσερα κρούσματα κορωνοϊού σε Άσυλο Α...  ...   Πυργιώτης 09/12/2020, 20:31 Τι πρωτόκολλο εφά...
# 7      Στα 1.677 τα νέα κρούσματα - 578 διασωληνωμέν...  ...   karantinatos 09/12/2020, 21:24 Άντε και του χ...
# 9      Δεν βλέπουμε την αναμενόμενη βελτίωση, λέει ο...  ...   Μα... πώς Μανώλη; 10/12/2020, 14:19 Αφού οι ε...
# ...

# %%
df1.comments.iloc[1]
# Out:
# ' Πυργιώτης 09/12/2020, 20:31 Τι πρωτόκολλο εφάρμοσες εκεί κ. Χαρδαλιά? Όπως αποδεικνύεται, οι ικανότητες σου σταματούν στα πρόστιμα που δίνεις σε γριούλες έξω από εκκλησίες. Απάντηση $$ !!!!! 09/12/2020, 20:29 ΝΟΣΟΚΟΜΕΙΑ ΓΗΡΟΚΟΜΕΙΑ ΦΥΛΑΚΕΣ ΙΔΡΥΜΑΤΑ....ΕΣΤΙΕΣ ΜΟΛΥΝΣΗΣ......ΠΟΛΥ ΕΥΚΟΛΟ ΝΑ ΤΑ ΕΛΕΓΞΟΥΝ...ΑΛΛΑ ΔΕΝ ΤΟ ΚΑΝΟΥΝ.....Ο ΚΟΣΜΟΣ ΠΡΟΣΕΧΕΙ......ΑΛΛΑ ΠΛΗΡΩΝΕΙ ΤΟ ΚΛΕΙΣΙΜΟ ΚΑΙ ΤΗΝ ΚΑΤΑΣΤΡΟΦΗ ΤΗΣ ΟΙΚΟΝΟΜΙΑΣ.....ΠΡΩΤΑ ΕΦΤΑΙΓΑΝ ΤΑ ΚΑΦΕ ΚΑΙ ΤΑ ΕΣΤΙΑΤΟΡΙΑ...ΚΑΤΕ ΜΕ ....ΛΑΘΟΣ.....ΤΩΡΑ Η ΟΙΚΟΓΕΝΕΙΑ....ΚΑΤΕΜΕ...ΛΑΘΟΣ.....ΚΑΙΡΟΣ ΝΑ ΜΠΟΥΝ ΤΑ ΠΡΑΓΜΑΤΑ ΣΤΗΝ ΘΕΣΗ ΤΟΥΣ...ΠΟΛΛΑ ΤΕΣΤ ΣΕ ΟΛΕΣ ΤΙΣ ΔΟΜΕΣ.....ΙΔΡΥΜΑΤΑ ...ΝΟΣΟΚΟΜΕΙΑ ΚΤΛ,....ΑΛΛΙΩΣ ΔΕΝ ΘΑ ΤΕΛΕΙΩΣΕΙ...Η ΠΑΝΔΗΜΙΑ Απάντηση '

# %%
#df1.comments.iloc[1].replace('\n','').replace('\r','')
# Out:
# '                        Πυργιώτης                    09/12/2020, 20:31                        Τι πρωτόκολλο εφάρμοσες εκεί κ. Χαρδαλιά? Όπως αποδεικνύεται,  οι ικανότητες σου σταματούν στα πρόστιμα που δίνεις σε γριούλες έξω από εκκλησίες.                     Απάντηση$$                        !!!!!                    09/12/2020, 20:29                        ΝΟΣΟΚΟΜΕΙΑ ΓΗΡΟΚΟΜΕΙΑ ΦΥΛΑΚΕΣ ΙΔΡΥΜΑΤΑ....ΕΣΤΙΕΣ ΜΟΛΥΝΣΗΣ......ΠΟΛΥ ΕΥΚΟΛΟ ΝΑ ΤΑ ΕΛΕΓΞΟΥΝ...ΑΛΛΑ ΔΕΝ ΤΟ ΚΑΝΟΥΝ.....Ο ΚΟΣΜΟΣ ΠΡΟΣΕΧΕΙ......ΑΛΛΑ ΠΛΗΡΩΝΕΙ ΤΟ ΚΛΕΙΣΙΜΟ ΚΑΙ ΤΗΝ ΚΑΤΑΣΤΡΟΦΗ ΤΗΣ ΟΙΚΟΝΟΜΙΑΣ.....ΠΡΩΤΑ ΕΦΤΑΙΓΑΝ ΤΑ ΚΑΦΕ ΚΑΙ ΤΑ ΕΣΤΙΑΤΟΡΙΑ...ΚΑΤΕ ΜΕ ....ΛΑΘΟΣ.....ΤΩΡΑ Η ΟΙΚΟΓΕΝΕΙΑ....ΚΑΤΕΜΕ...ΛΑΘΟΣ.....ΚΑΙΡΟΣ ΝΑ ΜΠΟΥΝ ΤΑ ΠΡΑΓΜΑΤΑ ΣΤΗΝ ΘΕΣΗ ΤΟΥΣ...ΠΟΛΛΑ ΤΕΣΤ ΣΕ ΟΛΕΣ ΤΙΣ ΔΟΜΕΣ.....ΙΔΡΥΜΑΤΑ ...ΝΟΣΟΚΟΜΕΙΑ ΚΤΛ,....ΑΛΛΙΩΣ ΔΕΝ ΘΑ  ΤΕΛΕΙΩΣΕΙ...Η ΠΑΝΔΗΜΙΑ                    Απάντηση'

# %%
#MEXRI FEBROYARIO

# %%
df2 = pd.read_csv("/gdrive/My Drive/Colab Notebooks/scrollcovidprotothemacomments.csv")
df2
# Out:
#                                                headline  ...                                           comments
# 0     \nΑπό λάθος ιδιωτικού εργαστηρίου τα 102 κρούσ...  ...  \n\n\r\n                        κοινος νους\r\...
# 1     \nΣωτήρης Τσιόδρας: Γιατί είναι σημαντικό το ε...  ...  \n\n\r\n                        Ο καταπληκτικό...
# 2     \nΥπό πίεση το ΕΣΥ: Νοσηλεύονται οι υπερτριπλά...  ...  \n\n\r\n                        Αχαχαχαχχχαχα\...
# 3     \nΣυγκινεί ο 8χρονος μέσα από τη ΜΕΘ του Ρίου:...  ...  \n\n\r\n                        λεων\r\n      ...
# 4     \n Μικρή μείωση στα κρούσματα - Ψηλά θάνατοι κ...  ...  \n\n\r\n                        Και καλύτερη ε...
# ...                                                 ...  ...                                                ...
# 1759  \nΚορωνοϊός: Αγωνία για το ύποπτο κρούσμα στο ...  ...  \n\n\r\n                        αυτο το πρωτο ...
# ...

# %%
df3 = df2.iloc[1717:1763]
df3
# Out:
#                                                headline  ...                                           comments
# 1717  \nΚορωνοϊός: Πώς ορίζεται το κρούσμα - Δείτε τ...  ...  \n\n\r\n                        Νέες οδηγίες\r...
# 1718  \nΚορωνοϊός-Κεραμέως: Δεν έχω εισήγηση για να ...  ...  \n\n\r\n                        Dear Kostas\r\...
# 1719  \nΚορωνοϊός: 14 νέα κρούσματα - Διασωληνώθηκε ...  ...  \n\n\r\n                        Αν ήταν ο Πολά...
# 1720  \nΚορωνοϊός: Πρωτοβουλία Κεραμέως για έκτακτη ...  ...  \n\n\r\n                        pp\r\n        ...
# 1721  \nΝέα κρούσματα κορωνοϊού στην Ελλάδα: Ανησυχί...  ...  \n\n\r\n                        μητσος\r\n    ...
# 1722  \nKρούσματα κορωνοϊού στην Ελλάδα: Περιμένουν ...  ...  \n\n\r\n                        ΠΡΟΣ ΠΡΩΤΟ ΘΕΜ...
# 1723  \nΚορωνοϊός: 31 τα καταγεγραμμένα κρούσματα - ...  ...  \n\n\r\n                        Κρητικός\r\n  ...
# ...

# %%
dfinal = pd.concat([df1, df3], axis=0,  ignore_index=True)
dfinal
# Out:
#                                                headline  ...                                           comments
# 0      Κρούσματα κορωνοϊού σε 50 περιοχές - Απαγορευ...  ...   Πόση 10/12/2020, 12:50 βλακεία πιά...με την Α...
# 1      Πάτρα: Τέσσερα κρούσματα κορωνοϊού σε Άσυλο Α...  ...   Πυργιώτης 09/12/2020, 20:31 Τι πρωτόκολλο εφά...
# 2      Στα 1.677 τα νέα κρούσματα - 578 διασωληνωμέν...  ...   karantinatos 09/12/2020, 21:24 Άντε και του χ...
# 3      Δεν βλέπουμε την αναμενόμενη βελτίωση, λέει ο...  ...   Μα... πώς Μανώλη; 10/12/2020, 14:19 Αφού οι ε...
# 4      Έχασε τη μάχη με τον κορωνοϊό 51χρονη διοικητ...  ...   mm 09/12/2020, 17:48 συλληπητηρια. στη χωρα μ...
# ...                                                 ...  ...                                                ...
# 3000  \nΚορωνοϊός: Πότε θα κλείνουν σχολεία, λιμάνια...  ...  \n\n\r\n                        kyriakos\r\n  ...
# ...

# %%
dfinal.replace(r'\s+|\\n', ' ', regex=True, inplace=True) 
dfinal
# Out:
#                                                headline  ...                                           comments
# 0      Κρούσματα κορωνοϊού σε 50 περιοχές - Απαγορευ...  ...   Πόση 10/12/2020, 12:50 βλακεία πιά...με την Α...
# 1      Πάτρα: Τέσσερα κρούσματα κορωνοϊού σε Άσυλο Α...  ...   Πυργιώτης 09/12/2020, 20:31 Τι πρωτόκολλο εφά...
# 2      Στα 1.677 τα νέα κρούσματα - 578 διασωληνωμέν...  ...   karantinatos 09/12/2020, 21:24 Άντε και του χ...
# 3      Δεν βλέπουμε την αναμενόμενη βελτίωση, λέει ο...  ...   Μα... πώς Μανώλη; 10/12/2020, 14:19 Αφού οι ε...
# 4      Έχασε τη μάχη με τον κορωνοϊό 51χρονη διοικητ...  ...   mm 09/12/2020, 17:48 συλληπητηρια. στη χωρα μ...
# ...                                                 ...  ...                                                ...
# 3000   Κορωνοϊός: Πότε θα κλείνουν σχολεία, λιμάνια,...  ...   kyriakos 26/02/2020, 14:13 Είπαμε ΠΡΙΝ ΑΠΌ ΠΟ...
# ...

# %%
dfinal.to_csv("/gdrive/My Drive/Colab Notebooks/finaldfprotothema.csv")
dfinal
# Out:
#                                                headline  ...                                           comments
# 0      Κρούσματα κορωνοϊού σε 50 περιοχές - Απαγορευ...  ...   Πόση 10/12/2020, 12:50 βλακεία πιά...με την Α...
# 1      Πάτρα: Τέσσερα κρούσματα κορωνοϊού σε Άσυλο Α...  ...   Πυργιώτης 09/12/2020, 20:31 Τι πρωτόκολλο εφά...
# 2      Στα 1.677 τα νέα κρούσματα - 578 διασωληνωμέν...  ...   karantinatos 09/12/2020, 21:24 Άντε και του χ...
# 3      Δεν βλέπουμε την αναμενόμενη βελτίωση, λέει ο...  ...   Μα... πώς Μανώλη; 10/12/2020, 14:19 Αφού οι ε...
# 4      Έχασε τη μάχη με τον κορωνοϊό 51χρονη διοικητ...  ...   mm 09/12/2020, 17:48 συλληπητηρια. στη χωρα μ...
# ...                                                 ...  ...                                                ...
# 3000   Κορωνοϊός: Πότε θα κλείνουν σχολεία, λιμάνια,...  ...   kyriakos 26/02/2020, 14:13 Είπαμε ΠΡΙΝ ΑΠΌ ΠΟ...
# ...

# %%
#NEWSBEAST

# %%
dffin = pd.read_csv("/gdrive/My Drive/Colab Notebooks/newsbeastend.csv")
dffin
# Out:
#       Unnamed: 0  ...        Date
# 0              1  ...  2020-10-12
# 1              4  ...  2020-08-12
# 2              5  ...  2020-08-12
# 3              6  ...  2020-10-12
# 4              8  ...  2020-09-12
# ...          ...  ...         ...
# 2295        3548  ...  2020-07-31
# 2296        3549  ...  2020-06-21
# 2297        3550  ...  2020-01-06
# 2298        3553  ...  2020-09-15
# 2299        3554  ...  2020-02-19
#
# [2300 rows x 7 columns]

# %%
dffin.sort_values(by='Date', ascending=False)
# Out:
#       Unnamed: 0  ...        Date
# 172          236  ...  2020-12-12
# 25            38  ...  2020-12-12
# 23            36  ...  2020-12-12
# 163          222  ...  2020-12-12
# 108          146  ...  2020-12-12
# ...          ...  ...         ...
# 626          924  ...  2020-01-04
# 815         1215  ...  2020-01-04
# 642          948  ...  2020-01-04
# 736         1097  ...  2020-01-03
# 1652        2555  ...  2020-01-03
#
# [2300 rows x 7 columns]

# %%
dffin.comments.iloc[2299]
# Out:
# 'γενοβεζικο που μετεφερε την ασθενεια απο τη μαυρη θαλασσα και μολυνθηκε εγινε επιδημια και τοτε οι θανατοι σε ημερησια βαση δεν ηταν πανω απο σαραντα.'

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/gdrive')
dfn = pd.read_csv("/gdrive/My Drive/Colab Notebooks/newsbeastend.csv")
dfn
# Out:
# Mounted at /gdrive
#       Unnamed: 0  ...        Date
# 0              1  ...  2020-10-12
# 1              4  ...  2020-08-12
# 2              5  ...  2020-08-12
# 3              6  ...  2020-10-12
# 4              8  ...  2020-09-12
# ...          ...  ...         ...
# 2295        3548  ...  2020-07-31
# 2296        3549  ...  2020-06-21
# 2297        3550  ...  2020-01-06
# 2298        3553  ...  2020-09-15
# 2299        3554  ...  2020-02-19
#
# [2300 rows x 7 columns]

# %%
dfn.comments.iloc[1]
# Out:
# 'Αυτός ο ιός έχει αφήσει άφωνη την ανθρωπότητα! Εξελίσσετε με τρομακτικούς ρυθμούς. Αρκεί ένας μασκαράς τύπου τσιορδα να πει ένα σύμπτωμα και ξαφνικά το παθαίνουν εκατομμύρια!Τώρα ο ιός μεταλαχθηκε και χτυπάει νέους, μετά θα χτυπάει όσους δεν κάνουν το σωτήριο εμβόλιο. Γενικά πάει όπου βολεύει.Βάλτε μάσκες!$$Ωχ! κύριε Τσιόρδα, σας βγάζουν ψεύτη!!Εσείς μας λέγανε ότι οι νέοι δεν έχουν πρόβλημα με τον κορονοιό, γιατί έχουν ειδικά ένζυμα και αντισώματα, να εδώ και μας δείχνατε την βάση της μύτης και έτσι δεν μπορούν να φέρουν ιϊκό φορτίο!!!Τώρα τι λένε αυτοί;Οι νέοι λέει αρρωσταίνουν και μάλιστα βαριά;Δεν τα έχετε συμφωνήσει καλά, μια έτσι, μια γιουβέτσι!!!$$Τρομερό, ευτυχώς στην Ελλάδα φαίνεται έχουμε διαφορετικό τύπο ιού μέχρι τώρα γιατί δεν επαληθευονται τα νούμερα .Από τις 12.000 κρούσματα έχουν διασωληνωθεί μέχρι τώρα γύρω στα 600 και από αυτά το 90% ηλικιωμένοι ή με προβλήματα υγείας.Οπότε ούτε οι ασθενείς με προβλήματα υγείας δεν φτάνουν το 10% που λέει η ερευνά, οι δε νέοι 18-34
# ...

# %%
dfn['Date'] = pd.to_datetime(dfn['date'], format='%d/%m/%Y', dayfirst=False)
dfn
# Out:
#       Unnamed: 0  ...       Date
# 0              1  ... 2020-12-10
# 1              4  ... 2020-12-08
# 2              5  ... 2020-12-08
# 3              6  ... 2020-12-10
# 4              8  ... 2020-12-09
# ...          ...  ...        ...
# 2295        3548  ... 2020-07-31
# 2296        3549  ... 2020-06-21
# 2297        3550  ... 2020-06-01
# 2298        3553  ... 2020-09-15
# 2299        3554  ... 2020-02-19
#
# [2300 rows x 7 columns]

# %%
dfn['Date'].tail(10)
# Out:
# 2290   2020-09-23
# 2291   2020-04-17
# 2292   2020-03-25
# 2293   2020-11-09
# 2294   2020-04-02
# 2295   2020-07-31
# 2296   2020-06-21
# 2297   2020-06-01
# 2298   2020-09-15
# 2299   2020-02-19
# Name: Date, dtype: datetime64[ns]

# %%
dfn.sort_values(by='Date', ascending=False)
# Out:
#       Unnamed: 0  ...       Date
# 23            36  ... 2020-12-12
# 186          251  ... 2020-12-12
# 20            33  ... 2020-12-12
# 195          264  ... 2020-12-12
# 140          189  ... 2020-12-12
# ...          ...  ...        ...
# 619          916  ... 2020-02-21
# 513          745  ... 2020-02-20
# 1897        2934  ... 2020-02-19
# 2299        3554  ... 2020-02-19
# 407          587  ... 2020-02-18
#
# [2300 rows x 7 columns]

# %%
dfn.to_csv("/gdrive/My Drive/Colab Notebooks/newsbeastend.csv")

# %%
olga =[]
for comment in dfn["comments"]:
  listcom = comment.splitlines()
  
  for com in listcom:
    olga.append(com)
  print(listcom)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
